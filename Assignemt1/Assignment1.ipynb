# %% [markdown]
# Assignmnet no 1

# %% [markdown]
# Name: Sarthak Zunjure

# %% [markdown]
# Roll No: 03

# %% [markdown]
# PRN : 1252090003

# %% [markdown]
# 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. Create Dataset and DataFrame

# %%
import pandas as pd
import numpy as np
data = {
"Student_ID": [10, 20, 30, 40, 50],
"Name": ["Sarthak", "Abhishek", "Shaurya", "Atharav", "Rushabh"],
"Age": [21, 22, np.nan, 21, 24],
"Gender": ["M", "M", "M", "M", "M"],
"Department": ["CSE-AI", "CSE", "CSE-AI", "AIDS", "AIML"],
"Marks": [85, 78, np.nan, 90, 0],
"Attendance": [92, 99, 95, 95, 0],
"Internship": ["Yes", "No", "Yes", "Yes", "No"]
}
df = pd.DataFrame(data)
df
# Out:
#    Student_ID      Name   Age Gender Department  Marks  Attendance Internship
# 0          10   Sarthak  21.0      M     CSE-AI   85.0          92        Yes
# 1          20  Abhishek  22.0      M        CSE   78.0          99         No
# 2          30   Shaurya   NaN      M     CSE-AI    NaN          95        Yes
# 3          40   Atharav  21.0      M       AIDS   90.0          95        Yes
# 4          50   Rushabh  24.0      M       AIML    0.0           0         No

# %% [markdown]
# 3. Finding Shape of DataFrame

# %%
print(df.shape)
# Out:
# (5, 8)

# %% [markdown]
# 4. Finding Missing Values in Each Column

# %%
print(df.isnull().sum())
# Out:
# Student_ID    0
# Name          0
# Age           1
# Gender        0
# Department    0
# Marks         1
# Attendance    0
# Internship    0
# dtype: int64

# %% [markdown]
# 5. Fetching Data Types of Each Column

# %%
print(df.dtypes)
# Out:
# Student_ID      int64
# Name           object
# Age           float64
# Gender         object
# Department     object
# Marks         float64
# Attendance      int64
# Internship     object
# dtype: object

# %% [markdown]
# 6. Counting Number of Zero Values

# %%
print((df == 0).sum())
# Out:
# Student_ID    0
# Name          0
# Age           0
# Gender        0
# Department    0
# Marks         1
# Attendance    1
# Internship    0
# dtype: int64

# %% [markdown]
# 7. Selecting First 3 Rows from Dataset

# %%
print(df.loc[:2])
# Out:
#    Student_ID      Name   Age Gender Department  Marks  Attendance Internship
# 0          10   Sarthak  21.0      M     CSE-AI   85.0          92        Yes
# 1          20  Abhishek  22.0      M        CSE   78.0          99         No
# 2          30   Shaurya   NaN      M     CSE-AI    NaN          95        Yes

# %% [markdown]
# 8. Selecting Name and Marks Columns

# %%
print(df[["Name", "Marks"]])
# Out:
#        Name  Marks
# 0   Sarthak   85.0
# 1  Abhishek   78.0
# 2   Shaurya    NaN
# 3   Atharav   90.0
# 4   Rushabh    0.0

# %% [markdown]
# 9. Sorting by Marks

# %%
print(df.sort_values(by="Marks"))
# Out:
#    Student_ID      Name   Age Gender Department  Marks  Attendance Internship
# 4          50   Rushabh  24.0      M       AIML    0.0           0         No
# 1          20  Abhishek  22.0      M        CSE   78.0          99         No
# 0          10   Sarthak  21.0      M     CSE-AI   85.0          92        Yes
# 3          40   Atharav  21.0      M       AIDS   90.0          95        Yes
# 2          30   Shaurya   NaN      M     CSE-AI    NaN          95        Yes

# %% [markdown]
# 10. Describe Attributes of Data

# %%
print(df.describe(include="all"))
# Out:
#         Student_ID     Name        Age Gender Department      Marks  \
# count     5.000000        5   4.000000      5          5   4.000000
# unique         NaN        5        NaN      1          4        NaN
# top            NaN  Sarthak        NaN      M     CSE-AI        NaN
# freq           NaN        1        NaN      5          2        NaN
# mean     30.000000      NaN  22.000000    NaN        NaN  63.250000
# std      15.811388      NaN   1.414214    NaN        NaN  42.452915
# min      10.000000      NaN  21.000000    NaN        NaN   0.000000
# 25%      20.000000      NaN  21.000000    NaN        NaN  58.500000
# 50%      30.000000      NaN  21.500000    NaN        NaN  81.500000
# 75%      40.000000      NaN  22.500000    NaN        NaN  86.250000
# max      50.000000      NaN  24.000000    NaN        NaN  90.000000
#
#         Attendance Internship
# count     5.000000          5
# unique         NaN          2
# top            NaN        Yes
# ...

# %% [markdown]
# 11. Rechecking Data Types and Dataset Information

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Age         4 non-null      float64
#  3   Gender      5 non-null      object
#  4   Department  5 non-null      object
#  5   Marks       4 non-null      float64
#  6   Attendance  5 non-null      int64
#  7   Internship  5 non-null      object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 452.0+ bytes
# None

# %% [markdown]
# 12. Counting Unique Values in Each Column

# %%
print(df.nunique())
# Out:
# Student_ID    5
# Name          5
# Age           3
# Gender        1
# Department    4
# Marks         4
# Attendance    4
# Internship    2
# dtype: int64

# %% [markdown]
# 13. Fetching Column Names

# %%
print(df.columns)
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'Marks',
#        'Attendance', 'Internship'],
#       dtype='object')

# %% [markdown]
# 14. Converting Data Types

# %%
df["Student_ID"] = df["Student_ID"].astype("int16")
df["Age"] = df["Age"].astype("float16")
df["Marks"] = df["Marks"].astype("float16")
df["Attendance"] = df["Attendance"].astype("int16")
print("Data Types After Converting:")
print(df.dtypes)
# Out:
# Data Types After Converting:
# Student_ID      int16
# Name           object
# Age           float16
# Gender         object
# Department     object
# Marks         float16
# Attendance      int16
# Internship     object
# dtype: object

# %% [markdown]
# Read data from different fromats (CSV, XLS)

# %%
df_csv = pd.read_csv("NY-House-Dataset.csv")
print(df_csv.head())
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %% [markdown]
# Find Shape of Data

# %%
print(df_csv.shape)
# Out:
# (4801, 17)

# %% [markdown]
# Find Missing Values

# %%
df_csv.isnull().sum()
# Out:
# BROKERTITLE                    0
# TYPE                           0
# PRICE                          0
# BEDS                           0
# BATH                           0
# PROPERTYSQFT                   0
# ADDRESS                        0
# STATE                          0
# MAIN_ADDRESS                   0
# ADMINISTRATIVE_AREA_LEVEL_2    0
# LOCALITY                       0
# SUBLOCALITY                    0
# STREET_NAME                    0
# LONG_NAME                      0
# FORMATTED_ADDRESS              0
# LATITUDE                       0
# LONGITUDE                      0
# dtype: int64

# %% [markdown]
# Data types

# %%
df_csv.dtypes
# Out:
# BROKERTITLE                     object
# TYPE                            object
# PRICE                            int64
# BEDS                             int64
# BATH                           float64
# PROPERTYSQFT                   float64
# ADDRESS                         object
# STATE                           object
# MAIN_ADDRESS                    object
# ADMINISTRATIVE_AREA_LEVEL_2     object
# LOCALITY                        object
# SUBLOCALITY                     object
# STREET_NAME                     object
# LONG_NAME                       object
# FORMATTED_ADDRESS               object
# LATITUDE                       float64
# LONGITUDE                      float64
# dtype: object

# %% [markdown]
# Find Zero values

# %%
(df_csv.select_dtypes(include=["number"]) == 0).sum()
# Out:
# PRICE           0
# BEDS            0
# BATH            3
# PROPERTYSQFT    0
# LATITUDE        0
# LONGITUDE       0
# dtype: int64

# %% [markdown]
# Indexing & selecting

# %% [markdown]
# Single column:

# %%
df_csv["PRICE"]
# Out:
# 0          315000
# 1       195000000
# 2          260000
# 3           69000
# 4        55000000
#           ...
# 4796       599000
# 4797       245000
# 4798      1275000
# 4799       598125
# 4800       349000
# Name: PRICE, Length: 4801, dtype: int64

# %% [markdown]
# Multiple columns:

# %%
df_csv[["PRICE", "BEDS", "BATH"]]
# Out:
#           PRICE  BEDS       BATH
# 0        315000     2   2.000000
# 1     195000000     7  10.000000
# 2        260000     4   2.000000
# 3         69000     3   1.000000
# 4      55000000     7   2.373861
# ...         ...   ...        ...
# 4796     599000     1   1.000000
# 4797     245000     1   1.000000
# 4798    1275000     1   1.000000
# 4799     598125     2   1.000000
# 4800     349000     1   1.000000
#
# [4801 rows x 3 columns]

# %% [markdown]
# First 5 rows:

# %%
df_csv.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %% [markdown]
# Rows with condition:

# %%
df_csv[df_csv["PRICE"] > 2000]
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %% [markdown]
# Sorting

# %% [markdown]
# Ascending

# %%
df_csv.sort_values(by="PRICE")
# Out:
#                                             BROKERTITLE                TYPE  \
# 317                 Brokered by Living NY - Main Office            For sale
# 310                 Brokered by Living NY - Main Office            For sale
# 360                 Brokered by Century 21 Realty First       Land for sale
# 463                Brokered by Morris Park Realty Group      Co-op for sale
# 979                                 Brokered by COMPASS      Condo for sale
# ...                                                 ...                 ...
# 141       Brokered by Douglas Elliman - 575 Madison Ave      House for sale
# 1075                                Brokered by COMPASS      Co-op for sale
# 69    Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 1                                   Brokered by Serhant      Condo for sale
# 304                   Brokered by ANNE LOPA REAL ESTATE      House for sale
#
#            PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %% [markdown]
# Descending:

# %%
df_csv.sort_values(by="PRICE", ascending=False)
# Out:
#                                             BROKERTITLE                TYPE  \
# 304                   Brokered by ANNE LOPA REAL ESTATE      House for sale
# 1                                   Brokered by Serhant      Condo for sale
# 69    Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 1075                                Brokered by COMPASS      Co-op for sale
# 141       Brokered by Douglas Elliman - 575 Madison Ave      House for sale
# ...                                                 ...                 ...
# 979                                 Brokered by COMPASS      Condo for sale
# 463                Brokered by Morris Park Realty Group      Co-op for sale
# 360                 Brokered by Century 21 Realty First       Land for sale
# 310                 Brokered by Living NY - Main Office            For sale
# 317                 Brokered by Living NY - Main Office            For sale
#
#            PRICE  BEDS       BATH  PROPERTYSQFT  \
# ...

# %% [markdown]
# Describe attributes

# %%
df_csv.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  4.801000e+03  4801.000000  4801.000000   4801.000000  4801.000000
# mean   2.356940e+06     3.356801     2.373861   2184.207862    40.714227
# std    3.135525e+07     2.602315     1.946962   2377.140894     0.087676
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.639375
# 50%    8.250000e+05     3.000000     2.000000   2184.207862    40.726749
# 75%    1.495000e+06     4.000000     3.000000   2184.207862    40.771923
# max    2.147484e+09    50.000000    50.000000  65535.000000    40.912729
#
#          LONGITUDE
# count  4801.000000
# mean    -73.941601
# std       0.101082
# min     -74.253033
# 25%     -73.987143
# 50%     -73.949189
# 75%     -73.870638
# max     -73.702450

# %% [markdown]
# All columns:

# %%
df_csv.describe(include="all")
# Out:
#                 BROKERTITLE            TYPE         PRICE         BEDS  \
# count                  4801            4801  4.801000e+03  4801.000000
# unique                 1036              13           NaN          NaN
# top     Brokered by COMPASS  Co-op for sale           NaN          NaN
# freq                    456            1450           NaN          NaN
# mean                    NaN             NaN  2.356940e+06     3.356801
# std                     NaN             NaN  3.135525e+07     2.602315
# min                     NaN             NaN  2.494000e+03     1.000000
# 25%                     NaN             NaN  4.990000e+05     2.000000
# 50%                     NaN             NaN  8.250000e+05     3.000000
# 75%                     NaN             NaN  1.495000e+06     4.000000
# max                     NaN             NaN  2.147484e+09    50.000000
#
#                BATH  PROPERTYSQFT                    ADDRESS  \
# ...

# %% [markdown]
# Dataset info

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %% [markdown]
# Counting unique values

# %%
df_csv.nunique()
# Out:
# BROKERTITLE                    1036
# TYPE                             13
# PRICE                          1274
# BEDS                             27
# BATH                             22
# PROPERTYSQFT                   1445
# ADDRESS                        4582
# STATE                           308
# MAIN_ADDRESS                   4583
# ADMINISTRATIVE_AREA_LEVEL_2      29
# LOCALITY                         11
# SUBLOCALITY                      21
# STREET_NAME                     174
# LONG_NAME                      2731
# FORMATTED_ADDRESS              4550
# LATITUDE                       4196
# LONGITUDE                      4118
# dtype: int64

# %% [markdown]
# Column names

# %%
df_csv.columns
# Out:
# Index(['BROKERTITLE', 'TYPE', 'PRICE', 'BEDS', 'BATH', 'PROPERTYSQFT',
#        'ADDRESS', 'STATE', 'MAIN_ADDRESS', 'ADMINISTRATIVE_AREA_LEVEL_2',
#        'LOCALITY', 'SUBLOCALITY', 'STREET_NAME', 'LONG_NAME',
#        'FORMATTED_ADDRESS', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %% [markdown]
# Datatype conversion

# %%
df_csv["BEDS"] = df_csv["BEDS"].astype("float16")
df_csv["BATH"] = df_csv["BATH"].astype("float16")
df_csv["PRICE"] = df_csv["PRICE"].astype("float32")
print("Data Types After Converting:")
print(df_csv.dtypes)
# Out:
# Data Types After Converting:
# BROKERTITLE                     object
# TYPE                            object
# PRICE                          float32
# BEDS                           float16
# BATH                           float16
# PROPERTYSQFT                   float64
# ADDRESS                         object
# STATE                           object
# MAIN_ADDRESS                    object
# ADMINISTRATIVE_AREA_LEVEL_2     object
# LOCALITY                        object
# SUBLOCALITY                     object
# STREET_NAME                     object
# LONG_NAME                       object
# FORMATTED_ADDRESS               object
# LATITUDE                       float64
# LONGITUDE                      float64
# dtype: object
