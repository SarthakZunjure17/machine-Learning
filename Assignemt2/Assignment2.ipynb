# %% [markdown]
# Assignment 2: Perofrm the following operations using Python on the data sets. Compute and Display summary statistics for each feature available in the dataset.Illustrate the feature distributions using histogram Data Cleaning, Data Integration, Data Transformation

# %% [markdown]
# Name : Sarthak Zunjure

# %% [markdown]
# Roll No: 03

# %% [markdown]
# PRN No:1252090003

# %% [markdown]
# 1. Import Libraries & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 2.Check Dataset Information

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# 3. Detect Missing Values

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# 4. Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# (a) Drop rows with missing values

# %%
df_drop = df.dropna()

# %% [markdown]
# 5. Remove Duplicate Records
#
# *   List item
# *   List item

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# 6 Final Cleaned Dataset

# %%
print(df.head())
df.to_csv("Iris.csv", index=False)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 8. Standardize / Normalize Data

# %%
def mean(values):
    total = 0
    count = 0
    for v in values:
        total += v
        count += 1
    return total / count


def median(values):
    values = sorted(values)
    n = len(values)
    mid = n // 2

    if n % 2 == 0:
        return (values[mid - 1] + values[mid]) / 2
    else:
        return values[mid]


def mode(values):
    freq = {}
    for v in values:
        freq[v] = freq.get(v, 0) + 1

    max_count = max(freq.values())

    modes = [k for k, v in freq.items() if v == max_count]

    if len(modes) == 1:
        return modes[0]
    else:
        return modes


def variance(values):
    m = mean(values)
    total = 0
    count = 0
    for v in values:
        total += (v - m) ** 2
        count += 1
    return total / count


def data_range(values):
    return max(values) - min(values)

# %%
df = pd.read_csv("Iris.csv")

col = "SepalLengthCm"

values = df[col].dropna().tolist()


# CALCULATE USING USER-DEFINED FUNCTIONS

print("USER-DEFINED RESULTS:")
print("Mean       :", mean(values))
print("Median     :", median(values))
print("Mode       :", mode(values))
print("Variance   :", variance(values))
print("Range      :", data_range(values))

# VERIFY USING INBUILT FUNCTIONS

print("\nINBUILT FUNCTION RESULTS:")
print("Mean       :", df[col].mean())
print("Median     :", df[col].median())
print("Mode       :", df[col].mode().tolist())
print("Variance   :", df[col].var(ddof=0))
print("Range      :", df[col].max() - df[col].min())

print("\nDESCRIBE OUTPUT:")
df.describe()
# Out:
# USER-DEFINED RESULTS:
# Mean       : 5.843333333333335
# Median     : 5.8
# Mode       : 5.0
# Variance   : 0.6811222222222222
# Range      : 3.6000000000000005
#
# INBUILT FUNCTION RESULTS:
# Mean       : 5.843333333333334
# Median     : 5.8
# Mode       : [5.0]
# Variance   : 0.6811222222222222
# Range      : 3.6000000000000005
#
# DESCRIBE OUTPUT:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# ...

# %% [markdown]
# Histogram for ALL numerical features:

# %%
df.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# Check missing values

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Handle missing values

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %% [markdown]
# Remove duplicate values

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Manual Statistics

# %%
numerical_df = df.select_dtypes(include=[np.number])

for col in numerical_df.columns:
          print("Feature:", col)
          print("Minimum Value:", numerical_df[col].min())
          print("Maximum Value:", numerical_df[col].max())
          print("Mean:", numerical_df[col].mean())
          print("Range:", numerical_df[col].max() - numerical_df[col].min())
          print("Standard Deviation:", numerical_df[col].std())
          print("Variance:", numerical_df[col].var())
          print("25th Percentile:", numerical_df[col].quantile(0.25))
          print("50th Percentile:", numerical_df[col].quantile(0.50))
          print("75th Percentile:", numerical_df[col].quantile(0.75))
          print("-" * 40)
# Out:
# Feature: Id
# Minimum Value: 1
# Maximum Value: 150
# Mean: 75.5
# Range: 149
# Standard Deviation: 43.445367992456916
# Variance: 1887.5
# 25th Percentile: 38.25
# 50th Percentile: 75.5
# 75th Percentile: 112.75
# ----------------------------------------
# Feature: SepalLengthCm
# Minimum Value: 4.3
# Maximum Value: 7.9
# Mean: 5.843333333333334
# Range: 3.6000000000000005
# Standard Deviation: 0.8280661279778629
# Variance: 0.6856935123042505
# 25th Percentile: 5.1
# 50th Percentile: 5.8
# 75th Percentile: 6.4
# ----------------------------------------
# Feature: SepalWidthCm
# Minimum Value: 2.0
# Maximum Value: 4.4
# Mean: 3.0540000000000003
# Range: 2.4000000000000004
# Standard Deviation: 0.4335943113621737
# Variance: 0.18800402684563763
# 25th Percentile: 2.8
# 50th Percentile: 3.0
# 75th Percentile: 3.3
# ----------------------------------------
# Feature: PetalLengthCm
# Minimum Value: 1.0
# Maximum Value: 6.9
# Mean: 3.758666666666666
# Range: 5.9
# ...

# %% [markdown]
# FEATURE DISTRIBUTION USING HISTOGRAM

# %%
numerical_df.hist(bins=10, figsize=(12,10))
plt.suptitle("Feature Distribution using Histogram")
plt.show()

# %% [markdown]
# DATA INTEGRATION

# %% [markdown]
# Vertical Data Integration (Row-wise)
# Combines datasets with same structure by stacking rows.

# %%
import pandas as pd

StudInfo1 = pd.DataFrame({
    'StdId': [1, 2],
    'Name': ['Sarthak', 'Shaurya']
})

StudInfo2 =  pd.DataFrame({
    'StdId': [3, 4],
    'Name': ['Atharv', 'Ganesh']
})

# Integrate data row-wise
stud_data = pd.concat([StudInfo1, StudInfo2], ignore_index=True)

print(stud_data)
# Out:
#    StdId     Name
# 0      1  Sarthak
# 1      2  Shaurya
# 2      3   Atharv
# 3      4   Ganesh

# %% [markdown]
# Horizontal Data Integration (Column-wise)                                Combines different attributes for the same entities.
# Student Academic & Attendance Data
#  Using concat(axis=1)

# %%
marks = pd.DataFrame({
    'RollNo': [101, 102, 103],
    'Marks': [85, 90, 88]
})

attendance = pd.DataFrame({
    'RollNo': [101, 102, 103],
    'Attendance': [92, 95, 90]
})

# Integrate data column-wise
student_data = pd.concat([marks, attendance['Attendance']], axis=1)

print(student_data)
# Out:
#    RollNo  Marks  Attendance
# 0     101     85          92
# 1     102     90          95
# 2     103     88          90

# %% [markdown]
# Key-based Data Integration (Joins)  Using merge()                      Integrates data based on a common key.

# %%
students = pd.DataFrame({
    'StudentID': [1, 2, 3],
    'Name': ['Amit', 'Neha', 'Rahul']
})

results = pd.DataFrame({
    'StudentID': [1, 2, 4],
    'CGPA': [8.5, 9.1,8.7]
})

# Inner Join
data_inner = pd.merge(students, results, on='StudentID', how='inner')

print(data_inner)
# Out:
#    StudentID  Name  CGPA
# 0          1  Amit   8.5
# 1          2  Neha   9.1

# %% [markdown]
# Types of Joins in Data Integration

# %%
pd.merge(students, results, on='StudentID', how='inner')   # Common records
# Out:
#    StudentID  Name  CGPA
# 0          1  Amit   8.5
# 1          2  Neha   9.1

# %%
pd.merge(students, results, on='StudentID', how='left')    # All left + matches
# Out:
#    StudentID   Name  CGPA
# 0          1   Amit   8.5
# 1          2   Neha   9.1
# 2          3  Rahul   NaN

# %%
pd.merge(students, results, on='StudentID', how='right')   # All right + matches
# Out:
#    StudentID  Name  CGPA
# 0          1  Amit   8.5
# 1          2  Neha   9.1
# 2          4   NaN   8.7

# %%
pd.merge(students, results, on='StudentID', how='outer')   # All records
# Out:
#    StudentID   Name  CGPA
# 0          1   Amit   8.5
# 1          2   Neha   9.1
# 2          3  Rahul   NaN
# 3          4    NaN   8.7

# %% [markdown]
# Integration Using Index Using join() Joins datasets using index instead of columns.

# %%
df1 = students.set_index('StudentID')
df2 = results.set_index('StudentID')

integrated_data = df1.join(df2)

print(integrated_data)
# Out:
#             Name  CGPA
# StudentID
# 1           Amit   8.5
# 2           Neha   9.1
# 3          Rahul   NaN

# %% [markdown]
# Integrating Data from Multiple File Formats

# %%
students.to_csv('student.csv', index=False)
results.to_excel('results.xlsx', index=False)

csv_data = pd.read_csv('student.csv')
excel_data = pd.read_excel('results.xlsx')

final_data = pd.merge(csv_data, excel_data, on='StudentID')

# %% [markdown]
# Handling Issues After Integration

# %% [markdown]
# Remove Duplicates

# %%
final_data.drop_duplicates(inplace=True)

# %% [markdown]
# Handle Missing Values

# %%
final_data.fillna(0, inplace=True)

# %% [markdown]
# Standardize Column Names

# %%
final_data.columns = final_data.columns.str.lower().str.strip()

# %% [markdown]
# Complete Data Integration Workflow

# %%
import pandas as pd

students = pd.read_csv("student.csv")
results = pd.read_excel("results.xlsx")

merged_data = pd.merge(students, results, on="StudentID", how="left")
print(merged_data)
# Out:
#    StudentID   Name  CGPA
# 0          1   Amit   8.5
# 1          2   Neha   9.1
# 2          3  Rahul   NaN

# %% [markdown]
# Data transformation

# %% [markdown]
# 1. MinMaxScaler vs StandardScaler
#
# Both are feature scaling techniques, but they work differently.

# %% [markdown]
# A. MinMaxScaler
#
# Purpose: Scales all numeric values to a fixed range, usually 0 to 1 (can be changed).
# Formula:
#
# 𝑋 scaled=𝑋−𝑋min/𝑋max −𝑋 min
#
# ⁡
# X_min = minimum value of feature
#
# X_max = maximum value of feature

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

df = pd.DataFrame({'Age':[18,22,25,30,35]})
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)
print(df_scaled)
# Out:
# [[0.        ]
#  [0.23529412]
#  [0.41176471]
#  [0.70588235]
#  [1.        ]]

# %% [markdown]
# When to use:
#
# Data is not normally distributed
#
# You need fixed range for all features
#
# Algorithms like Neural Networks, KNN, SVM are sensitive to scale

# %% [markdown]
# A. Scaling / Normalization / Standardization
#
# Purpose: Make numerical features comparable.

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import pandas as pd

# Sample data
df = pd.DataFrame({'Age':[18,22,25,30], 'Salary':[25000,50000,60000,80000]})

# Min-Max Normalization
scaler = MinMaxScaler()
df[['Age','Salary']] = scaler.fit_transform(df[['Age','Salary']])
print("Min-Max Scaled:\n", df)

# Standardization (Z-score)
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[['Age','Salary']])
print("Standardized:\n", df_scaled)
# Out:
# Min-Max Scaled:
#          Age    Salary
# 0  0.000000  0.000000
# 1  0.333333  0.454545
# 2  0.583333  0.636364
# 3  1.000000  1.000000
# Standardized:
#  [[-1.31267933 -1.45174713]
#  [-0.3995111  -0.18935832]
#  [ 0.28536507  0.3155972 ]
#  [ 1.42682536  1.32550825]]
